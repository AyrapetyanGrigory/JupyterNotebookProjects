# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
df[["medv", "dis"]]
# Out:
#      medv     dis
# 0    24.0  4.0900
# 1    21.6  4.9671
# 2    33.4  6.0622
# 3    36.2  6.0622
# 4    22.9  5.5605
# ..    ...     ...
# 328  17.5  2.3999
# 329  22.4  2.4786
# 330  20.6  2.2875
# 331  23.9  2.1675
# 332  11.9  2.5050
#
# [333 rows x 2 columns]

# %%
plt.plot(df['dis'], df['medv'],  "bo", "-", )
plt.xlabel("Weighted mean of distances to five Boston employment centres")
plt.ylabel("Median value of owner-occupied homes in $1000s")
plt.title("Medv on Dis value dependancy")
# Out:
# Text(0.5, 1.0, 'Medv on Dis value dependancy')

# %%
df["medv"]
# Out:
# 0      24.0
# 1      21.6
# 2      33.4
# 3      36.2
# 4      22.9
#        ...
# 328    17.5
# 329    22.4
# 330    20.6
# 331    23.9
# 332    11.9
# Name: medv, Length: 333, dtype: float64

# %%
df["medv"].mean()
# Out:
# 22.76876876876877

# %%
df[df["medv"] > df["medv"].mean()]
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 11    17   1.05393   0.0   8.14     0  0.538  5.935   29.3  4.4986    4  307
# ..   ...       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 265  408  11.95110   0.0  18.10     0  0.659  5.608  100.0  1.2852   24  666
# 310  473   3.56868   0.0  18.10     0  0.580  6.437   75.0  2.8965   24  666
# 316  481   5.82401   0.0  18.10     0  0.532  6.242   64.7  3.4242   24  666
# 317  482   5.70818   0.0  18.10     0  0.532  6.750   74.9  3.3317   24  666
# 331  504   0.06076   0.0  11.93     0  0.573  6.976   91.0  2.1675    1  273
#
#      ptratio   black  lstat  medv
# ...
